# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque


def get_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    return [urljoin(url, a['href']) for a in soup.find_all('a', href=True)]


def bfs_traversal(start_url, num_layers, graph):
    visited = set()
    queue = deque([(start_url, 0)])

    while queue:
        url, layer = queue.popleft()
        if layer > num_layers:
            break
        if url not in visited:
            visited.add(url)
            connections = get_links(url)

            graph.add_node(url)

            for x in connections:
                graph.add_edge(url, x)
                queue.append((x, layer + 1))


scan_layers = 1
entrance = "https://www.youtube.com/"

graph = nx.Graph()
seed = 0
pos = nx.spring_layout(graph, k=0.5, iterations=50)
bfs_traversal(entrance, scan_layers, graph)


print(graph.nodes)
print(graph.edges)


# Add pos to the node
for n, p in pos.items():
    graph.nodes[n]['pos'] = p


# Plotly code
import plotly.graph_objects as go

edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5,color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in graph.edges():
    x0, y0 = graph.nodes[edge[0]]['pos']
    x1, y1 = graph.nodes[edge[1]]['pos']
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])


node_x = []
node_y = []
for node in graph.nodes():
    x, y = graph.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(graph.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append('# of connections: '+str(len(adjacencies[1])))

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="Python code: <a href='https://plotly.com/ipython-notebooks/network-graphs/'> https://plotly.com/ipython-notebooks/network-graphs/</a>",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002 ) ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()
# Out:
# ['https://www.youtube.com/', 'https://www.youtube.com/about/', 'https://www.youtube.com/about/press/', 'https://www.youtube.com/about/copyright/', 'https://www.youtube.com/t/contact_us/', 'https://www.youtube.com/creators/', 'https://www.youtube.com/ads/', 'https://developers.google.com/youtube', 'https://www.youtube.com/t/terms', 'https://www.youtube.com/t/privacy', 'https://www.youtube.com/about/policies/', 'https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen', 'https://www.youtube.com/new', 'https://tv.youtube.com/learn/nflsundayticket', 'https://www.youtube.com/about/#content', 'https://www.youtube.com/howyoutubeworks/', 'https://www.youtube.com/trends/', 'https://blog.you
https://www.youtube.com/t/privacy'), ('https://www.youtube.com/', 'https://www.youtube.com/about/policies/'), ('https://www.youtube.com/', 'https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen'), ('https://www.youtube.com/', 'https://www.youtube.com/new'), ('https://www.youtube.com/', 'https://tv.youtube.com/learn/nflsundayticket'), ('https://www.youtube.com/about/', 'https://www.youtube.com/about/#content'), ('https://www.youtube.com/about/', 'https://www.youtube.com/howyoutubeworks/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/creators/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/trends/'), ('https://www.youtube.com/about/', 'https://blog.youtube/'), ('https://www.youtube.com/about/', 'https://twitter.com/YouTube'), ('https://www.youtube.com/about/', 'https://www.instagram.com/youtube/'), ('https://www.youtube.com/about/', 'https://www.facebook.com/youtube/?ref=br_r'), ('https://www.youtube.com/about/', 'https://www.youtube.com/about/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/jobs/'), ('https://www.youtube.com/about/', 'https://blog.youtube/press/'), ('https://www.youtube.com/about/', 'https://tv.youtube.com/learn/nflsundayticket'), ('https://www.youtube.com/about/', 'https://www.youtube.com/kids/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/musicpremium'), ('https://www.youtube.com/about/', 'https://www.youtube.com/channel/UCqVDpXKLmKeBU_yyt_QkItQ'), ('https://www.youtube.com/about/', 'https://www.youtube.com/creators/podcasts/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/premium/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/ads/youtube-select/'), ('https://www.youtube.com/about/', 'https://studio.youtube.com/'), ('https://www.youtube.com/about/', 'https://tv.youtube.com/'), ('https://www.youtube.com/about/', 'https://developers.google.com/youtube'), ('https://www.youtube.com/about/', 'https://www.youtube.com/ads/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/yt/family/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/creatorresearch/'), ('https://www.youtube.com/about/', 'https://servicesdirectory.withyoutube.com/'), ('https://www.youtube.com/about/', 'https://artists.youtube.com/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/nextup/'), ('https://www.youtube.com/about/', 'https://vr.youtube.com/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/creators-for-change/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/csai-match/'), ('https://www.youtube.com/about/', 'https://socialimpact.youtube.com/'), ('https://www.youtube.com/about/', 'https://www.youtube.com'), ('https://www.youtube.com/about/', 'https://www.youtube.com/about/policies/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/about/copyright/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/about/brand-resources/'), ('https://www.youtube.com/about/', 'https://www.google.com/policies/privacy/'), ('https://www.youtube.com/about/', 'https://www.youtube.com/t/terms'), ('https://www.youtube.com/about/', 'https://support.google.com/youtube/#topic=9257498'), ('https://ww ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 63
#      55 edge_trace = go.Scatter(
#      56     x=[],
#      57     y=[],
#      58     line=dict(width=0.5,color='#888'),
#      59     hoverinfo='none',
#      60     mode='lines')
#      62 for edge in graph.edges():
# ---> 63     x0, y0 = graph.nodes[edge[0]]['pos']
#      64     x1, y1 = graph.nodes[edge[1]]['pos']
#      65     edge_trace['x'] += tuple([x0, x1, None])
#
# KeyError: 'pos'
